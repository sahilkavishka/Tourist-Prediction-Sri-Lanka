# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv("touristData.csv")
df.head()
# Out:
#    year    month   originCountry  totalCount  dollarRate  \
# 0  2024  January           India       34399       315.7
# 1  2024  January          Russia       31159       315.7
# 2  2024  January  United Kingdom       16665       315.7
# 3  2024  January         Germany       13593       315.7
# 4  2024  January           China       11511       315.7
#
#    apparent_temperature_mean_celcius  sunshine_duration_seconds  rain_sum_mm  \
# 0                          30.787654                33462.04969      7.67284
# 1                          30.787654                33462.04969      7.67284
# 2                          30.787654                33462.04969      7.67284
# 3                          30.787654                33462.04969      7.67284
# 4                          30.787654                33462.04969      7.67284
#
#    precipitation_hours  num_establishments  num_rooms  AirPassengerFaresIndex  \
# ...

# %%
df.shape
# Out:
# (750, 13)

# %%
df.isnull().sum()
# Out:
# year                                 0
# month                                0
# originCountry                        0
# totalCount                           0
# dollarRate                           0
# apparent_temperature_mean_celcius    0
# sunshine_duration_seconds            0
# rain_sum_mm                          0
# precipitation_hours                  0
# num_establishments                   0
# num_rooms                            0
# AirPassengerFaresIndex               0
# consumerPriceIndex                   0
# dtype: int64

# %%
df.dtypes
# Out:
# year                                   int64
# month                                 object
# originCountry                         object
# totalCount                             int64
# dollarRate                           float64
# apparent_temperature_mean_celcius    float64
# sunshine_duration_seconds            float64
# rain_sum_mm                          float64
# precipitation_hours                  float64
# num_establishments                     int64
# num_rooms                              int64
# AirPassengerFaresIndex               float64
# consumerPriceIndex                   float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   year                               750 non-null    int64
#  1   month                              750 non-null    object
#  2   originCountry                      750 non-null    object
#  3   totalCount                         750 non-null    int64
#  4   dollarRate                         750 non-null    float64
#  5   apparent_temperature_mean_celcius  750 non-null    float64
#  6   sunshine_duration_seconds          750 non-null    float64
#  7   rain_sum_mm                        750 non-null    float64
#  8   precipitation_hours                750 non-null    float64
#  9   num_establishments                 750 non-null    int64
#  10  num_rooms                          750 non-null    int64
# ...

# %%
df.head(2)
# Out:
#    year    month originCountry  totalCount  dollarRate  \
# 0  2024  January         India       34399       315.7
# 1  2024  January        Russia       31159       315.7
#
#    apparent_temperature_mean_celcius  sunshine_duration_seconds  rain_sum_mm  \
# 0                          30.787654                33462.04969      7.67284
# 1                          30.787654                33462.04969      7.67284
#
#    precipitation_hours  num_establishments  num_rooms  AirPassengerFaresIndex  \
# 0             7.012346                4519      55455                   178.0
# 1             7.012346                4519      55455                   178.0
#
#    consumerPriceIndex
# 0               185.5
# 1               251.3

# %%
df.corr(numeric_only=True)['totalCount']
# Out:
# year                                -0.118207
# totalCount                           1.000000
# dollarRate                          -0.111067
# apparent_temperature_mean_celcius    0.194328
# sunshine_duration_seconds            0.165637
# rain_sum_mm                         -0.147451
# precipitation_hours                 -0.254570
# num_establishments                  -0.166978
# num_rooms                           -0.137467
# AirPassengerFaresIndex               0.241346
# consumerPriceIndex                   0.153506
# Name: totalCount, dtype: float64

# %%
select = ['year', 'month', 'originCountry', 'dollarRate', 'consumerPriceIndex', 'totalCount']


data = df[select]

data = data.dropna() 
data = data.drop_duplicates() 

print(data.dtypes)
print(data.shape)
# Out:
# year                    int64
# month                  object
# originCountry          object
# dollarRate            float64
# consumerPriceIndex    float64
# totalCount              int64
# dtype: object
# (750, 6)

# %%
df['month'] = df['month'].str.strip()
df['originCountry'] = df['originCountry'].str.strip()
select = ['year', 'month', 'originCountry', 'dollarRate', 'consumerPriceIndex', 'totalCount']
data = df[select]
data = data.dropna()
data = data.drop_duplicates()

print(data.dtypes)
print(data.shape)
# Out:
# year                    int64
# month                  object
# originCountry          object
# dollarRate            float64
# consumerPriceIndex    float64
# totalCount              int64
# dtype: object
# (750, 6)

# %%
data.to_csv("cleaned_tourist.csv",index=False)
